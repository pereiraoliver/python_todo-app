# %%
import pandas as pd
os.chdir("..")
print(os.getcwd())
# Out:
# C:\Users\perei\Documents\MyLearn\2026-07_Udemy_PythonMegaCourse_ArditSulce\App4_Your_Weather_API\Proj2_Wine_Tasting

# %%
df = pd.read_csv("downloads/wines.csv")

# %%
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'name', 'points', 'price',
#        'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='str')

# %% [markdown]
# ## How many wines received a rating of 100 points?

# %%
df.loc[df['points'] == 100]['points'].count()
# Out:
# np.int64(19)

# %% [markdown]
# ## What is the name of the most expensive wine?

# %%
df.loc[df['price'] == df['price'].max()]['name'].squeeze()
# Out:
# 'Glamorosa Sensible'

# %% [markdown]
# ## Create a new column containing the wine ratings on a scale of 0 to 5.
# - The original ratings are on a scale of 0 to 100.
# - Floating-point values are allowed, such as 2.3, 4.1, etc.

# %%
df['ratings'] = df['points'] / 20

# %%
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %% [markdown]
# ## Create a histogram showing the prices of wines that cost less than $100.

# %%
df.loc[df['price'] < 100]['price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Create a scatter plot with:
# - X-axis: Wine price
# - Y-axis: Wine rating/points
# - Use the plot to investigate whether wine ratings increase as price increases.

# %%
df.plot.scatter(x='price', y='ratings', figsize=(15,3))
# Out:
# <Axes: xlabel='price', ylabel='ratings'>
