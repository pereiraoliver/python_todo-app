# %%
import pandas as pd

# %%
df = pd.read_csv("downloads/dictionary.csv")

# %%
print(df)
# Out:
#                             word  \
# 0      abandoned industrial site
# 1              abandoned vehicle
# 2                 abiotic factor
# 3                    access road
# 4              access to the sea
# ...                          ...
# 49532                     casing
# 49533                     facing
# 49534                     lining
# 49535         assumption of Mary
# 49536               auscultation
#
#                                               definition
# 0      Site that cannot be used for any purpose, bein...
# 1      A vehicle that has been discarded in the envir...
# 2      Physical, chemical and other non-living enviro...
# 3      Any street or narrow stretch of paved surface ...
# 4      The ability to bring goods to and from a port ...
# ...                                                  ...
# 49532  Something put around something else, usually i...
# 49533  Something put around something else, usually i...
# ...

# %%
df.columns
# Out:
# Index(['word', 'definition'], dtype='str')

# %%
df[['word', 'definition']]
# Out:
#                             word  \
# 0      abandoned industrial site
# 1              abandoned vehicle
# 2                 abiotic factor
# 3                    access road
# 4              access to the sea
# ...                          ...
# 49532                     casing
# 49533                     facing
# 49534                     lining
# 49535         assumption of Mary
# 49536               auscultation
#
#                                               definition
# 0      Site that cannot be used for any purpose, bein...
# 1      A vehicle that has been discarded in the envir...
# 2      Physical, chemical and other non-living enviro...
# 3      Any street or narrow stretch of paved surface ...
# 4      The ability to bring goods to and from a port ...
# ...                                                  ...
# 49532  Something put around something else, usually i...
# 49533  Something put around something else, usually i...
# ...

# %%
df.loc[df['word'] == 'lining']['definition']
# Out:
# 49534    Something put around something else, usually i...
# Name: definition, dtype: str

# %%
import os
os.chdir('..')
print(os.getcwd())
# Out:
# C:\Users\perei\Documents\MyLearn\2026-07_Udemy_PythonMegaCourse_ArditSulce\App4_Your_Weather_API

# %%
pd.read_csv("downloads/data_small/stations.txt", skiprows=17)
# Out:
#       STAID  STANAME                                   CN        LAT  \
# 0         1  VAEXJOE                                   SE  +56:52:00
# 1         2  FALUN                                     SE  +60:37:00
# 2         3  STENSELE                                  SE  +65:04:00
# 3         4  LINKOEPING                                SE  +58:24:00
# 4         5  LINKOEPING-MALMSLAETT                     SE  +58:24:00
# ...     ...                                       ...  ..        ...
# 6449  25149  LEBORK                                    PL  +54:33:11
# 6450  25150  GDANSK-REBIECHOWO_OLD                     PL  +54:22:59
# 6451  25151  ELBLAG-MILEJEWO                           PL  +54:13:23
# 6452  25156  KROSNO                                    PL  +49:42:24
# 6453  25157  YLJA KRAFTVERK                            NO  +61:11:49
#
#              LON  HGHT
# 0     +014:48:00   166
# 1     +015:37:00   160
# 2     +017:09:59   325
# 3     +015:31:59    93
# ...
